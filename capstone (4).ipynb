# %% [markdown]
# # Capstone Project - The Battle of the Neighborhoods (Week 2)
# ### Applied Data Science Capstone by IBM/Coursera

# %% [markdown]
# ## Table of contents
# * [Introduction: Business Problem](#introduction)
# * [Data](#data)
# * [Analysis](#analysis)
# * [Results and Discussion](#results)
# * [Conclusion](#conclusion)

# %% [markdown]
# ## Introduction: Business Problem <a name="introduction"></a>

# %% [markdown]
# In this project, we will try to obtain data on the different restaurant categories in the city of **Chennai in Tamil Nadu, India** (It was chosen because it was my hometown) and cluster them into different categories based on the incidence of the restaurants in each neighborhood within a radius of 1km from the location centre.

# %% [markdown]
# This report will be targeted at stakeholders that are interested in **opening a restaurant** in the city of chennai and desire to know the **different restaurant categories in Chennai** and the **cuisines of highest and lowest frequency** in each given area.

# %% [markdown]
# ## Data <a name="data"></a>

# %% [markdown]
# Based on definition of our problem, factors that will influence our decission are:
# * The number of restaurants in a given neighborhood
# * The different restaurant classifications
# * The abundance or lack of restaurants in a given area as well as its distance from the city centre
#
# The data sources used to extract the required information:
# * The centre of the city of chennai is obtained using the **geocoder method**
# * The different neighborhoods and their respective latitudes and longitudes have to be webscraped from **https://chennaiiq.com/chennai/latitude_longitude_areas.asp**
# * The different venues in the individual neighborhoods are obtained using the **Foursquare API** using the explore? call
# * The haversine formula is obtained from a website that works on calculating minimum distance along the earths surface between two points using their latitude and longitude values

# %% [markdown]
# **We import all the necessary libraries for the capstone project in the below cell**

# %%
from bs4 import BeautifulSoup
import numpy as np
import pandas as pd
import urllib.request
from urllib.request import urlopen
import requests
import re
import os
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from matplotlib import colors
from matplotlib import cm

# %% [markdown]
# **Do not use the next cell while viewing the file**

# %% [markdown]
# **While testing, viewing the entire rows and columns of the dataframe is very useful and can be done by setting all the set_option parameters to None**

# %%
pd.set_option('display.max_rows',20)
pd.set_option('display.max_columns', 20)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# ### Getting the latitudes and longitude of all neighborhoods in chennai

# %% [markdown]
# From analysing the internet, a website was found that listed the different Neighborhoods in the city of Chennai in the country of India and the respective location coordinates (latitudes and longitudes). The website URL was copied and was **webscarped** using the **Beautiful soup module** in python

# %%
url='https://chennaiiq.com/chennai/latitude_longitude_areas.asp'
page=requests.get(url)
soup=BeautifulSoup(page.text,'html.parser')
tables=soup.find_all('table',{'class':'TBox'})
tables
# Out:
# [<table align="center" border="0" cellpadding="3" cellspacing="1" class="TBox" width="70%">
#  <tr class="tabH">
#  <td colspan="4">List of Chennai City Latitude Longitude (Madras)</td>
#  </tr>
#  <tr class="tabH1">
#  <td>S.No.</td>
#  <td>Location</td>
#  <td>Latitude</td>
#  <td>Longitude</td>
#  </tr>
#  <tr class="tab"><td align="right">1</td><td> Adyar Bus Debot.</td><td> 12°59'50" N</td><td> 80°15'25" E</td></tr><tr class="tab"><td align="right">2</td><td> Adyar Signal</td><td> 13°00'23" N</td><td> 80°15'27" E</td></tr><tr class="tab"><td align="right">3</td><td> Alandur</td><td> 13°00'28" N</td><td> 80°12'35" E</td></tr><tr class="tab"><td align="right">4</td><td> Ambattur</td><td> 13°06'36" N</td><td> 80°10'12" E</td></tr><tr class="tab"><td align="right">5</td><td> Anna Arch</td><td> 13°04'28" N</td><td> 80°13'06" E</td></tr><tr class="tab"><td align="right">6</td><td> Anna Nagar Roundana</td><td> 13°05'04" N</td><td> 80°13'05" E</td></tr><tr class="tab"><td align="right">7</td><td> Anna Nagar West Terminus</td><td> 13°05'35" N</td><td> 80°11'55" E</td></tr><tr class="tab"><td align="right">8</td><td> Anna Statue</td><td> 13°04'05" N</td><td> 80°16'19" E</td></tr><tr class="tab"><td align="right">9</td><td> Anna University Entrance</td><td> 13°00'29" N</td><td> 80°14'06" E</td></tr><tr class="tab"><td align="right">10</td><td> Avadi</td><td> 13°07'13" N</td><td> 80°06'36" E</td></tr><tr class="tab"><td align="right">11</td><td> AVM Studio</td><td> 13°02'52" N</td><td> 80°12'18" E</td></tr><tr class="tab"><td align="right">12</td><td> Ayyappa Temple</td><td> 13°03'23" N</td><td> 80°13'54" E</td></tr><tr class="tab"><td align="right">13</td><td> Basin Bridge</td><td> 13°06'08" N</td><td> 80°16'17" E</td></tr><tr class="tab"><td align="right">14</td><td> Chennai Airport</td><td> 12°59'32" N</td><td> 80°10'10" E</td></tr><tr class="tab"><td align="right">15</td><td> Chennai Central</td><td> 13°04'56" N</td><td> 80°16'32" E</td></tr><tr class="tab"><td align="right">16</td><td> Chennai Mofussil Bus Terminas (CMBT)</td><td> 13°04'04" N</td><td> 80°12'21" E</td></tr><tr class="tab"><td align="right">17</td><td> Chennai Trade Center</td><td> 13°00'53" N</td><td> 80°11'28" E</td></tr><tr class="tab"><td align="right">18</td><td> Chepaukam Stadium</td><td> 13°03'51" N</td><td> 80°15'59" E</td></tr><tr class="tab"><td align="right">19</td><td> chetput</td><td> 13°04'24" N</td><td> 80°14'34" E</td></tr><tr class="tab"><td align="right">20</td><td> Chintadripet</td><td> 13°04'18" N</td><td> 80°16'26" E</td></tr><tr class="tab"><td align="right">21</td><td> Chintamani Signal</td><td> 13°05'06" N</td><td> 80°13'27" E</td></tr><tr class="tab"><td align="right">22</td><td> Chola</td><td> 13°02'39" N</td><td> 80°15'35" E</td></tr><tr class="tab"><td align="right">23</td><td> Church Park</td><td> 13°03'14" N</td><td> 80°15'16" E</td></tr><tr class="tab"><td align="right">24</td><td> CIPET</td><td> 13°00'51" N</td><td> 80°12'17" E</td></tr><tr class="tab"><td align="right">25</td><td> CIT Nagar Roundana</td><td> 13°01'52" N</td><td> 80°14'14" E</td></tr><tr class="tab"><td align="right">26</td><td> CLRI</td><td> 13°00'28" N</td><td> 80°14'33" E</td></tr><tr class="tab"><td align="right">27</td><td> DPI</td><td> 13°04'05" N</td><td> 80°14'55" E</td></tr><tr class="tab"><td align="right">28</td><td> Egmore Railway Station</td><td> 13°04'40" N</td><td> 80°15'42" E</td></tr><tr class="tab"><td align="right">29</td><td> Ethiraj College</td><td> 13°03'49" N</td><td> 80°15'26" E</td></tr><tr class="tab"><td align="right">30</td><td> Gemini Flyover</td><td> 13°03'08" N</td><td> 80°15'04" E</td></tr><tr class="tab"><td align="right">31</td><td> Greams Road</td><td> 13°03'23" N</td><td> 80°15'18" E</td></tr><tr class="tab"><td align="right">32</td><td> Guindy Race Course</td><td> 13°00'17" N</td><td> 80°13'01" E</td></tr><tr class="tab"><td align="right">33</td><td> Guindy Railway Station</td><td> 13°00'30" N</td><td> 80°12'45" E</td></tr><tr class="tab"><td align="right">34</td><td> HTL Colony</td><td> 13°01'05" N</td><td> 80°12'28" E</td></tr><tr class="tab"><td align="right">35</td><td> IIT Madras</td><td> 13°00'19" N</td><td> 80°14'31" E</td></tr><tr class="tab"><td align="right">36</td><td> Indra Nagar, Adyar</td><td> 12°59'56" N</td><td> 80°15 ...
#  <tr class="tab">
#  <td colspan="4"> </td>
#  </tr>
#  <tr class="tabH">
#  <td colspan="4"> </td>
#  </tr>
#  </table>]

# %% [markdown]
# ### Getting the information into a dataframe

# %% [markdown]
# The information is demarcated by <tr> for the rows and <td> for the elements in the given row. By using find_all function and finding all the markers, we can extract the data into suitable lists and convert it to a pandas dataframe.

# %%
latitude=[]
Neighborhood=[]
longitude=[]
for table in tables:
    rows=table.find_all('tr')
    for row in rows:
        cells=row.find_all('td')
        if(len(cells)>1):
            location=cells[1]
            Neighborhood.append(location.text.strip())
                
            lat=cells[2]
            latitude.append(lat.text.strip())
                
            long=cells[3]
            longitude.append(long.text.strip())

# %%
df=pd.DataFrame(Neighborhood,columns=['Neighborhood'])
df['latitude']=latitude
df['longitude']=longitude
df.head()
# Out:
#        Neighborhood     latitude    longitude
# 0          Location     Latitude    Longitude
# 1  Adyar Bus Debot.  12°59'50" N  80°15'25" E
# 2      Adyar Signal  13°00'23" N  80°15'27" E
# 3           Alandur  13°00'28" N  80°12'35" E
# 4          Ambattur  13°06'36" N  80°10'12" E

# %%
df.shape
# Out:
# (106, 3)

# %%
df.drop(0,axis=0,inplace=True)
df.head()
# Out:
#        Neighborhood     latitude    longitude
# 1  Adyar Bus Debot.  12°59'50" N  80°15'25" E
# 2      Adyar Signal  13°00'23" N  80°15'27" E
# 3           Alandur  13°00'28" N  80°12'35" E
# 4          Ambattur  13°06'36" N  80°10'12" E
# 5         Anna Arch  13°04'28" N  80°13'06" E

# %%
df.shape
# Out:
# (105, 3)

# %% [markdown]
# The data that we obtained is in **degrees, minutes and seconds format** and is in the form of a string. It is not easy to feed this data into a folium map and is difficult to work with. By using **regular expressions** in python, we can extract and modify the different elements to match the **decimal format**

# %% [markdown]
# **Perform string operation to convert the location data from dms(degrees minutes seconds) to decimals**

# %% [markdown]
# The below chunk of code takes a latitude or longitude string with has its value in **DMS system and N/S/E/W** instead of **positive or negative signs**. This converts any location data to decimal location information.

# %%
def dms_to_dec_latlng(lat,long):
    min_pat=re.compile(r'[°](\d{2})[\']')
    sec_pat=re.compile(r'[\'](\d{2})[\"]')
    minutes_lat=(float(min_pat.search(lat).group(1)))/60
    seconds_lat=(float(sec_pat.search(lat).group(1)))/3600
    minutes_long=(float(min_pat.search(long).group(1)))/60
    seconds_long=(float(sec_pat.search(long).group(1)))/3600
    dec_lat=minutes_lat+seconds_lat
    dec_long=minutes_long+seconds_long
    pattern_south=re.compile(r'S$')
    pattern_west=re.compile(r'W$')
    south=pattern_south.search(lat)
    west=pattern_west.search(long)
    if (south==None):
        if (west==None):
            return [(float(lat[0:2])+dec_lat),(float(long[0:2])+dec_long)]
        else:
            return [(float(lat[0:2])+dec_lat),((float(long[0:2])+dec_long))*(-1)]
    else:
        if(west==None):
            return [((float(lat[0:2])+dec_lat))*(-1),(float(long[0:2])+dec_long)]
        else:
            return [((float(lat[0:2])+dec_lat))*(-1),((float(long[0:2])+dec_long))*(-1)]

# %%
for index in range(1,(df.shape[0]+1)):
    lat=df.loc[index,'latitude']
    lng=df.loc[index,'longitude']
    fixed_loc=dms_to_dec_latlng(lat,lng)
    df.at[index,'latitude']=fixed_loc[0]
    df.at[index,'longitude']=fixed_loc[1]

# %%
df.head(105)
# Out:
#                Neighborhood latitude longitude
# 1          Adyar Bus Debot.  12.9972   80.2569
# 2              Adyar Signal  13.0064   80.2575
# 3                   Alandur  13.0078   80.2097
# 4                  Ambattur    13.11     80.17
# 5                 Anna Arch  13.0744   80.2183
# ..                      ...      ...       ...
# 101  Velachery Bus Terminus  12.9758   80.2208
# 102             Villivakkam    13.11   80.2033
# 103             Vyasar Padi  13.1092   80.2625
# 104            Washermanpet  13.1086   80.2811
# 105      Woodlands Drive In    13.05   80.2511
#
# [105 rows x 3 columns]

# %%
df=df.astype({'latitude':'float64','longitude':'float64'})

# %% [markdown]
# ### To obtain the latitude and longitude of the centre of Chennai city

# %% [markdown]
# This is done using the geopy.geocoders library

# %%
from geopy.geocoders import Nominatim
import folium

# %%
address='Chennai, Tamil Nadu, India'
geolocator = Nominatim(user_agent="chennai_explorer")
location = geolocator.geocode(address)
ch_lat = location.latitude
ch_lng = location.longitude
print(ch_lat,ch_lng)
# Out:
# 13.0801721 80.2838331

# %% [markdown]
# ### Plot a map centered on Chennai and showing the different neighborhoods in the city

# %%
chennai_map=folium.Map([ch_lat,ch_lng],zoom_start=11)
folium.CircleMarker([ch_lat,ch_lng],radius=12,popup='Chennai',fill=True,fill_color='#FF2D00',fill_opacity=0.8).add_to(chennai_map)

for lat,lng,neigh in zip(df.latitude,df.longitude,df.Neighborhood):
    folium.CircleMarker([lat,lng],radius=6,popup=neigh,fill=True,fill_color='#0032FF',fill_opacity=0.7).add_to(chennai_map)
chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## To access the Foursquare API and retrieve information regarding venues in Chennai

# %% [markdown]
# The client ID / Secret and version are prespecified to reduce the need to respecify where needed

# %%
CLIENT_ID = 'GIL5KFTBUZBWMUCEWGMC1NISL2E1BFTEWROCHKPEJDBQVU2M' 
CLIENT_SECRET = 'TBEJZQQAZ4SCSEZ2WZIJ2GPTOMO4C1ZQ4FI5OC5YBSJKT450'
VERSION = '20200404' 
radius=1000
LIMIT=100

# %% [markdown]
# **The foursquare explore? and categories? endpoint methods are tested and based on the data retrieved, the explore? method is utilized**

# %%
url_categories = 'https://api.foursquare.com/v2/venues/categories?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, ch_lat, ch_lng, radius, LIMIT)
print(url_categories)
# Out:
# https://api.foursquare.com/v2/venues/categories?&client_id=GIL5KFTBUZBWMUCEWGMC1NISL2E1BFTEWROCHKPEJDBQVU2M&client_secret=TBEJZQQAZ4SCSEZ2WZIJ2GPTOMO4C1ZQ4FI5OC5YBSJKT450&v=20200404&ll=13.0801721,80.2838331&radius=1000&limit=100

# %% [markdown]
# ### Using a loop  to perform foursquare api calls for each neighborhood and storing that data in a dataframe

# %%
def get_nearby_venues(names,latitude,longitude,radius=1000):
    venues_list=[]
    LIMIT=100
    for name,lat,lng in zip(names,latitude,longitude):
        url='https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, VERSION, lat, lng, radius, LIMIT)
        result=requests.get(url).json()['response']['groups'][0]['items']
        venues_list.append([(
            name,
            lat,
            lng,
            v['venue']['name'],
            v['venue']['location']['lat'],
            v['venue']['location']['lng'],
            v['venue']['categories'][0]['name']) for v in result])
    
    nearby_venues=pd.DataFrame([item for venue_list in venues_list for item in venue_list])
    nearby_venues.columns=['Neighborhood','Area Latitude','Area Longitude','Venue Name','Venue Latitude','Venue Longitude','Venue Category']
    return (nearby_venues)

# %%
chennai_venues=get_nearby_venues(df.Neighborhood,df.latitude,df.longitude)

# %% [markdown]
# ## Since foursquare api has a limited number of calls, put the venues into a csv file to prevent calling it again later

# %%
chennai_venues.to_csv("chennai_venues.csv", header=True, index=False, encoding="utf-8")

# %%
chennai_venues=pd.read_csv('/Users/Karthik/Desktop/Python folder/chennai_venues.csv')
chennai_venues.head()
# Out:
#        Neighborhood  Area Latitude  Area Longitude                Venue Name  \
# 0  Adyar Bus Debot.      12.997222       80.256944        Zaitoon Restaurant
# 1  Adyar Bus Debot.      12.997222       80.256944      Kuttanadu Restaurant
# 2  Adyar Bus Debot.      12.997222       80.256944                  Zha Cafe
# 3  Adyar Bus Debot.      12.997222       80.256944  Kovai Pazhamudir Nilayam
# 4  Adyar Bus Debot.      12.997222       80.256944            Domino's Pizza
#
#    Venue Latitude  Venue Longitude             Venue Category
# 0       12.996861        80.256178  Middle Eastern Restaurant
# 1       12.997010        80.257799           Asian Restaurant
# 2       12.999730        80.254806                       Café
# 3       12.996522        80.259776    Fruit & Vegetable Store
# 4       13.002000        80.254000                Pizza Place

# %% [markdown]
# ### Unique venue categories in chennai_venues

# %% [markdown]
# The different types of venues in the city of chennai are obtained below

# %%
venue_list=chennai_venues['Venue Category'].unique()
print(venue_list.shape[0])
venue_list
# Out:
# 182
# array(['Middle Eastern Restaurant', 'Asian Restaurant', 'Café',
#        'Fruit & Vegetable Store', 'Pizza Place', 'Fast Food Restaurant',
#        "Women's Store", 'Indian Restaurant', 'Chinese Restaurant',
#        'Diner', 'Sandwich Place', 'Gym', 'BBQ Joint', 'Hotel',
#        'Multiplex', 'Movie Theater', 'Arcade', 'Breakfast Spot',
#        'Electronics Store', 'Hotel Bar', 'Juice Bar', 'Bakery',
#        'Ice Cream Shop', 'Pharmacy', 'Shopping Mall',
#        'North Indian Restaurant', 'Vegetarian / Vegan Restaurant',
#        'Grocery Store', 'Bookstore', 'Dessert Shop', 'Rock Club',
#        'Lounge', 'Snack Place', 'Mediterranean Restaurant',
#        'Italian Restaurant', 'Coffee Shop', 'Department Store',
#        'Comfort Food Restaurant', 'Furniture / Home Store',
#        'Gourmet Shop', 'Bus Station', 'Bar', 'Pool Hall', 'Airport',
#        'Golf Course', 'Cafeteria', 'Supermarket', 'Gas Station',
#        'Clothing Store', 'South Indian Restaurant', 'Scenic Lookout',
#        'Food', 'Sporting Goods Shop', 'Pub', 'Event Space', 'Park',
#        'Restaurant', 'Burger Joint', 'Paper / Office Supplies Store',
#        'Shoe Store', 'Farmers Market', 'Bistro', 'Bank', 'Jewelry Store',
#        'Tennis Court', 'Metro Station', 'Print Shop', 'Mobile Phone Shop',
#        'General Entertainment', 'Cricket Ground', 'Flea Market',
#        'Sports Club', 'College Cafeteria', 'State / Provincial Park',
#        'Zoo Exhibit', 'Train Station', 'Theater', 'Market', 'Music Store',
#        'Tennis Stadium', 'Bus Stop', 'Platform', 'Light Rail Station',
#        'ATM', 'Donut Shop', 'Airport Lounge', 'Airport Terminal', 'Road',
#        'Business Service', 'Airport Food Court', 'Nightclub',
#        'Soccer Stadium', 'Flower Shop', 'Bus Line', 'Food Court', 'Pool',
#        'Multicuisine Indian Restaurant', 'Korean Restaurant',
#        'Athletics & Sports', 'Rajasthani Restaurant', 'Steakhouse',
#        'Toy / Game Store', 'Bowling Alley', 'Mexican Restaurant',
#        'American Restaurant', 'Halal Restaurant', 'Concert Hall',
#        'Daycare', 'Bed & Breakfast', 'African Restaurant',
#        'Kerala Restaurant', 'Garden', 'Arts & Crafts Store', 'Tea Room',
#        'Thai Restaurant', 'Buffet', 'Smoke Shop', 'Gaming Cafe',
#        'Kebab Restaurant', "Men's Store", 'Bengali Restaurant',
#        'Japanese Curry Restaurant', 'Hookah Bar', 'Portuguese Restaurant',
#        'Gym Pool', 'Sports Bar', 'Cocktail Bar', 'Playground',
#        'Seafood Restaurant', 'Chocolate Shop', 'Convenience Store',
#        'Japanese Restaurant', 'Museum', 'Motel', 'Amphitheater',
#        'Molecular Gastronomy Restaurant', 'Whisky Bar', 'Spa',
#        'Watch Shop', 'Modern European Restaurant', 'Recreation Center',
#        'Russian Restaurant', 'Hyderabadi Restaurant', 'Beach', 'Boutique',
#        'Miscellaneous Shop', 'Pet Store', 'Indie Movie Theater',
#        'Antique Shop', 'Lighthouse', 'Sculpture Garden',
#        'Gym / Fitness Center', 'Yoga Studio', 'IT Services', 'Food Truck',
#        'Andhra Restaurant', 'Food & Drink Shop', 'Fried Chicken Joint',
#        'Salon / Barbershop', 'Burrito Place', 'Outlet Store',
#        'Cosmetics Shop', 'Malay Restaurant', 'Music Venue', 'Video Store',
#        'Harbor / Marina', 'Moving Target', 'Historic Site', 'Train',
#        'College Library', 'Hospital', 'Travel & Transport', 'Church',
#        'Office', 'Hostel', 'Indian Sweet Shop', 'New American Restaurant',
#        'Performing Arts Venue', 'Tourist Information Center',
#        'Music School', 'Falafel Restaurant', 'Accessories Store'],
#       dtype=object)

# %% [markdown]
# ## By analysing the above list, a simple loop is written to extract only the various types of restaurants and food establishments into a dataframe for furthur analysis

# %%
Neighborhood=[]
venue=[]
category=[]
venue_lat=[]
venue_lng=[]
for i in range(0,chennai_venues.shape[0]):
    cell=chennai_venues.loc[i,'Venue Category']
    a=cell.split(" ")
    results=[a[-1]=='Restaurant',
             a[-1]=='Place',
             a[-1]=='Joint',
             a[0]=='Cafe',
             a[0]=='Diner',
             a[0]=='Steakhouse',
             a[0]=='Buffet',
             a[0]=='Bistro',
             a[0]=='Cafeteria',
             a[0]=='Food',
             a[0]=='Breakfast',
             a[-1]=='Breakfast',
             a[0]=='Dessert',
             a[0]=='Coffee',
             a[0]=='Juice']
    if any(results):
        Neighborhood.append(chennai_venues.loc[i,'Neighborhood'])
        venue.append(chennai_venues.loc[i,'Venue Name'])
        category.append(chennai_venues.loc[i,'Venue Category'])
        venue_lat.append(chennai_venues.loc[i,'Venue Latitude'])
        venue_lng.append(chennai_venues.loc[i,'Venue Longitude'])

# %%
dataset={'Neighborhood':Neighborhood,'Venue Name':venue,'Venue Latitude':venue_lat,'Venue Longitude':venue_lng,'Venue Category':category}
chennai_restaurants=pd.DataFrame(data=dataset)
print(chennai_restaurants.shape)
chennai_restaurants.head()
# Out:
# (1850, 5)
#        Neighborhood                         Venue Name  Venue Latitude  \
# 0  Adyar Bus Debot.                 Zaitoon Restaurant       12.996861
# 1  Adyar Bus Debot.               Kuttanadu Restaurant       12.997010
# 2  Adyar Bus Debot.                     Domino's Pizza       13.002000
# 3  Adyar Bus Debot.  Adyar Ananda Bhavan, Besant Nagar       12.996678
# 4  Adyar Bus Debot.                Adyar Ananda Bhavan       13.005824
#
#    Venue Longitude             Venue Category
# 0        80.256178  Middle Eastern Restaurant
# 1        80.257799           Asian Restaurant
# 2        80.254000                Pizza Place
# 3        80.258275       Fast Food Restaurant
# 4        80.257368          Indian Restaurant

# %% [markdown]
# ## Analysis <a name="analysis"></a>

# %% [markdown]
# ### The different types of restaurants and their counts

# %% [markdown]
# **The different restaurant categories are obtained below**

# %%
restaurants=chennai_restaurants['Venue Category'].unique()
print(restaurants.shape[0])
restaurants
# Out:
# 56
# array(['Middle Eastern Restaurant', 'Asian Restaurant', 'Pizza Place',
#        'Fast Food Restaurant', 'Indian Restaurant', 'Chinese Restaurant',
#        'Diner', 'Sandwich Place', 'BBQ Joint', 'Breakfast Spot',
#        'Juice Bar', 'North Indian Restaurant',
#        'Vegetarian / Vegan Restaurant', 'Dessert Shop', 'Snack Place',
#        'Mediterranean Restaurant', 'Italian Restaurant', 'Coffee Shop',
#        'Comfort Food Restaurant', 'Cafeteria', 'South Indian Restaurant',
#        'Food', 'Restaurant', 'Burger Joint', 'Bistro', 'Food Court',
#        'Multicuisine Indian Restaurant', 'Korean Restaurant',
#        'Rajasthani Restaurant', 'Steakhouse', 'Mexican Restaurant',
#        'American Restaurant', 'Halal Restaurant', 'Bed & Breakfast',
#        'African Restaurant', 'Kerala Restaurant', 'Thai Restaurant',
#        'Buffet', 'Kebab Restaurant', 'Bengali Restaurant',
#        'Japanese Curry Restaurant', 'Portuguese Restaurant',
#        'Seafood Restaurant', 'Japanese Restaurant',
#        'Molecular Gastronomy Restaurant', 'Modern European Restaurant',
#        'Russian Restaurant', 'Hyderabadi Restaurant', 'Food Truck',
#        'Andhra Restaurant', 'Food & Drink Shop', 'Fried Chicken Joint',
#        'Burrito Place', 'Malay Restaurant', 'New American Restaurant',
#        'Falafel Restaurant'], dtype=object)

# %% [markdown]
# **The total count of each venue category is obtained and placed in a table**

# %%
restaurants=chennai_restaurants.groupby(['Venue Category']).count()
restaurants.drop(['Venue Name','Venue Latitude','Venue Longitude'],axis=1,inplace=True)
restaurants.sort_values(by='Neighborhood',ascending=False,inplace=True)
restaurants
# Out:
#                       Neighborhood
# Venue Category
# Indian Restaurant              625
# Chinese Restaurant             115
# Pizza Place                     92
# Fast Food Restaurant            84
# Coffee Shop                     83
# ...                            ...
# Andhra Restaurant                1
# Food Truck                       1
# Bed & Breakfast                  1
# Burrito Place                    1
# Fried Chicken Joint              1
#
# [56 rows x 1 columns]

# %% [markdown]
# ## Splitting the data into one dataframe with High frequency categories and one with low frequency categories

# %% [markdown]
# **The data is split up into high frequency restaurants and low frequency restaurants in order to perform clustering seperately without having one skew the other**

# %%
restaurants=restaurants.astype({'Neighborhood':'int64'})
restaurants.reset_index(inplace=True)

# %%
highfreq_rest=restaurants[restaurants['Neighborhood']>=10]
lowfreq_rest=restaurants[restaurants['Neighborhood']<10]

# %%
hfr=list(highfreq_rest['Venue Category'])
lfr=list(lowfreq_rest['Venue Category'])

# %%
chennai_rest_lowfreq=chennai_restaurants
for i in range(0,chennai_restaurants.shape[0]):
    cell=chennai_restaurants.loc[i,'Venue Category']
    for ele in hfr:
        if cell==ele:
            chennai_rest_lowfreq=chennai_rest_lowfreq.drop(i,axis=0)
            break

# %% [markdown]
# **This dataframe represents the distributiion of low frequcy restaurant catrgories in the city of chennai**

# %%
chennai_rest_lowfreq.head()
# Out:
#        Neighborhood             Venue Name  Venue Latitude  Venue Longitude  \
# 0  Adyar Bus Debot.  Grand Sweets & Snacks       13.000950        80.261203
# 1      Adyar Signal       Bombay Brassiere       13.006961        80.256419
# 2      Adyar Signal  Daawat The Kebab Shop       13.006689        80.253728
# 3      Adyar Signal             Azzuri Bay       13.011110        80.253922
# 4      Adyar Signal  Grand Sweets & Snacks       13.000950        80.261203
#
#              Venue Category
# 0                     Diner
# 1   North Indian Restaurant
# 2   North Indian Restaurant
# 3  Mediterranean Restaurant
# 4                     Diner

# %%
chennai_rest_lowfreq.shape
# Out:
# (138, 5)

# %%
chennai_rest_lowfreq.reset_index(inplace=True)
chennai_restaurants.reset_index(inplace=True)

# %% [markdown]
# **To find the mutually disjoint sets of chennai_restaurants and the low_freq_restaurants**

# %%
chennai_rest_highfreq=pd.concat([chennai_restaurants,chennai_rest_lowfreq,chennai_rest_lowfreq]).drop_duplicates(keep=False)

# %%
chennai_rest_highfreq.reset_index(inplace=True)

# %%
chennai_restaurants.drop(['index'],axis=1,inplace=True)
chennai_rest_lowfreq.drop(['index'],axis=1,inplace=True)
chennai_rest_highfreq.drop(['level_0','index'],axis=1,inplace=True)

# %%
chennai_rest_highfreq.head()
# Out:
#        Neighborhood                         Venue Name  Venue Latitude  \
# 0  Adyar Bus Debot.                 Zaitoon Restaurant       12.996861
# 1  Adyar Bus Debot.               Kuttanadu Restaurant       12.997010
# 2  Adyar Bus Debot.                     Domino's Pizza       13.002000
# 3  Adyar Bus Debot.  Adyar Ananda Bhavan, Besant Nagar       12.996678
# 4  Adyar Bus Debot.                Adyar Ananda Bhavan       13.005824
#
#    Venue Longitude             Venue Category
# 0        80.256178  Middle Eastern Restaurant
# 1        80.257799           Asian Restaurant
# 2        80.254000                Pizza Place
# 3        80.258275       Fast Food Restaurant
# 4        80.257368          Indian Restaurant

# %% [markdown]
# ## A small note to keep track of the different dataframe names used in the notebook

# %% [markdown]
# **chennai_venues -> Different venues in chennai**

# %% [markdown]
# **chennai_restaurants -> Restaurants in chennai**

# %% [markdown]
# **restaurants -> Categories of diff restaurants and their count**

# %% [markdown]
# **chennai_rest_highfreq -> High frequency restaurant distribution**

# %% [markdown]
# **chennai_rest_lowfreq -> Low frequency restaurant distribution**

# %% [markdown]
# ## The pandas get dummies method is used on the high and low frequency dataframes to prepare them for kmeans clustering

# %%
def dummies(dataframe):
    final=pd.get_dummies(dataframe[['Venue Category']],prefix="",prefix_sep="")
    final['Neighborhood']=dataframe['Neighborhood']
    fixed_columns=[final.columns[-1]]+list(final.columns[:-1])
    final=final[fixed_columns]
    final=final.groupby(['Neighborhood']).mean()
    return final

# %%
hf_rest_onehot=dummies(chennai_rest_highfreq)
hf_rest_onehot.head()
# Out:
#                   Asian Restaurant  BBQ Joint  Bistro  Breakfast Spot  Buffet  \
# Neighborhood
# AVM Studio                0.095238   0.047619     0.0        0.000000     0.0
# Adyar Bus Debot.          0.090909   0.045455     0.0        0.045455     0.0
# Adyar Signal              0.029412   0.000000     0.0        0.000000     0.0
# Alandur                   0.000000   0.000000     0.0        0.000000     0.0
# Ambattur                  0.000000   0.000000     0.0        0.000000     0.0
#
#                   Burger Joint  Chinese Restaurant  Coffee Shop  Dessert Shop  \
# Neighborhood
# AVM Studio                 0.0            0.000000     0.000000      0.000000
# Adyar Bus Debot.           0.0            0.045455     0.000000      0.000000
# Adyar Signal               0.0            0.029412     0.029412      0.058824
# Alandur                    0.0            0.000000     0.000000      0.000000
# Ambattur                   0.0            0.000000     0.000000      0.000000
#
#                   Fast Food Restaurant  ...  Juice Bar  Kebab Restaurant  \
# Neighborhood                            ...
# AVM Studio                    0.095238  ...   0.000000               0.0
# Adyar Bus Debot.              0.090909  ...   0.045455               0.0
# Adyar Signal                  0.058824  ...   0.058824               0.0
# Alandur                       0.000000  ...   0.000000               0.0
# Ambattur                      0.000000  ...   0.000000               0.0
#
#                   Middle Eastern Restaurant  Pizza Place  Restaurant  \
# Neighborhood
# AVM Studio                         0.000000     0.095238    0.047619
# Adyar Bus Debot.                   0.045455     0.136364    0.000000
# Adyar Signal                       0.000000     0.088235    0.000000
# Alandur                            0.000000     0.000000    0.000000
# Ambattur                           0.000000     1.000000    0.000000
#
#                   Sandwich Place  Snack Place  South Indian Restaurant  \
# Neighborhood
# AVM Studio              0.000000     0.047619                 0.047619
# Adyar Bus Debot.        0.045455     0.000000                 0.000000
# Adyar Signal            0.029412     0.029412                 0.000000
# Alandur                 0.000000     0.000000                 0.000000
# Ambattur                0.000000     0.000000                 0.000000
#
#                   Thai Restaurant  Vegetarian / Vegan Restaurant
# Neighborhood
# AVM Studio                    0.0                       0.095238
# Adyar Bus Debot.              0.0                       0.000000
# Adyar Signal                  0.0                       0.058824
# Alandur                       0.0                       0.000000
# Ambattur                      0.0                       0.000000
#
# [5 rows x 24 columns]

# %%
lf_rest_onehot=dummies(chennai_rest_lowfreq)
lf_rest_onehot.head()
# Out:
#                   African Restaurant  American Restaurant  Andhra Restaurant  \
# Neighborhood
# Adyar Bus Debot.                 0.0                  0.0                0.0
# Adyar Signal                     0.0                  0.0                0.0
# Alandur                          0.0                  0.0                0.0
# Anna Arch                        0.0                  0.0                0.0
# CIPET                            0.0                  0.0                0.0
#
#                   Bed & Breakfast  Bengali Restaurant  Burrito Place  \
# Neighborhood
# Adyar Bus Debot.              0.0                 0.0            0.0
# Adyar Signal                  0.0                 0.0            0.0
# Alandur                       0.0                 0.0            0.0
# Anna Arch                     0.0                 0.0            0.0
# CIPET                         0.0                 0.0            0.0
#
#                   Cafeteria  Comfort Food Restaurant  Diner  \
# Neighborhood
# Adyar Bus Debot.        0.0                      0.0    1.0
# Adyar Signal            0.0                      0.2    0.2
# Alandur                 1.0                      0.0    0.0
# Anna Arch               0.0                      0.0    0.0
# CIPET                   1.0                      0.0    0.0
#
#                   Falafel Restaurant  ...  Modern European Restaurant  \
# Neighborhood                          ...
# Adyar Bus Debot.                 0.0  ...                         0.0
# Adyar Signal                     0.0  ...                         0.0
# Alandur                          0.0  ...                         0.0
# Anna Arch                        0.0  ...                         0.0
# CIPET                            0.0  ...                         0.0
#
#                   Molecular Gastronomy Restaurant  \
# Neighborhood
# Adyar Bus Debot.                              0.0
# Adyar Signal                                  0.0
# Alandur                                       0.0
# Anna Arch                                     0.0
# CIPET                                         0.0
#
#                   Multicuisine Indian Restaurant  New American Restaurant  \
# Neighborhood
# Adyar Bus Debot.                             0.0                      0.0
# Adyar Signal                                 0.0                      0.0
# Alandur                                      0.0                      0.0
# Anna Arch                                    0.0                      0.0
# CIPET                                        0.0                      0.0
#
#                   North Indian Restaurant  Portuguese Restaurant  \
# Neighborhood
# Adyar Bus Debot.                      0.0                    0.0
# Adyar Signal                          0.4                    0.0
# Alandur                               0.0                    0.0
# Anna Arch                             0.0                    0.0
# CIPET                                 0.0                    0.0
#
#                   Rajasthani Restaurant  Russian Restaurant  \
# Neighborhood
# Adyar Bus Debot.                    0.0                 0.0
# Adyar Signal                        0.0                 0.0
# Alandur                             0.0                 0.0
# Anna Arch                           0.0                 0.0
# CIPET                               0.0                 0.0
#
#                   Seafood Restaurant  Steakhouse
# Neighborhood
# Adyar Bus Debot.                 0.0         0.0
# Adyar Signal                     0.0         0.0
# Alandur                          0.0         0.0
# Anna Arch                        0.0         0.0
# CIPET                            0.0         0.0
#
# [5 rows x 32 columns]

# %% [markdown]
# ## Performing k means clustering on the datasets

# %%
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

# %%
hf_rest_onehot.reset_index(inplace=True)
lf_rest_onehot.reset_index(inplace=True)

# %%
hf_clustering=hf_rest_onehot.drop('Neighborhood',1)
lf_clustering=lf_rest_onehot.drop('Neighborhood',1)

# %% [markdown]
# ### Looping through the different cluster values choosing the k value at the elbow point based on the sum of squares error

# %%
sse_hf={}
sse_lf={}
for k in range(1,20):
    kmeans_hf=KMeans(n_clusters=k).fit(hf_clustering)
    kmeans_lf=KMeans(n_clusters=k).fit(lf_clustering)
    sse_hf[k]=kmeans_hf.inertia_
    sse_lf[k]=kmeans_lf.inertia_

# %% [markdown]
# **k=7 is the elbow point for the high frequency data**

# %%
plt.figure()
plt.plot(list(sse_hf.keys()), list(sse_hf.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# **around k=15 seems to be the elbow point here**

# %%
plt.figure()
plt.plot(list(sse_lf.keys()), list(sse_lf.values()))
plt.xlabel("Number of cluster")
plt.ylabel("SSE")
plt.show()

# %% [markdown]
# ### The values of k are chosen as 7 and 15 for the high and low frequency sets

# %%
k_hf=7
k_lf=15
kmeans_hf=KMeans(n_clusters=k_hf).fit(hf_clustering)
kmeans_lf=KMeans(n_clusters=k_lf).fit(lf_clustering)

# %% [markdown]
# ### Create a dataframe that lists the different categories in descending order of their predominance in an area and the cluster labels are added to the dataframe

# %%
def return_most_common_venues(row, num_top_venues):
    row_categories = row.iloc[1:]
    row_categories_sorted = row_categories.sort_values(ascending=False)
    
    return row_categories_sorted.index.values[0:num_top_venues]

# %%
def column_names(num_top_venues):
    indicators = ['st', 'nd', 'rd']
    columns = ['Neighborhood']
    for ind in np.arange(num_top_venues-1):
        try:
            columns.append('{}{} Most Common Venue'.format(ind+1, indicators[ind]))
        except:
            columns.append('{}th Most Common Venue'.format(ind+1))
    
    return columns
            
hf_rest_sorted=pd.DataFrame(columns=column_names(hf_rest_onehot.shape[1]))
lf_rest_sorted=pd.DataFrame(columns=column_names(lf_rest_onehot.shape[1]))

hf_rest_sorted['Neighborhood']=hf_rest_onehot['Neighborhood']
lf_rest_sorted['Neighborhood']=lf_rest_onehot['Neighborhood']

for ind in np.arange(hf_rest_onehot.shape[0]):
    hf_rest_sorted.iloc[ind, 1:] = return_most_common_venues(hf_rest_onehot.iloc[ind, :], hf_rest_onehot.shape[1])
                            
for ind in np.arange(lf_rest_onehot.shape[0]):
    lf_rest_sorted.iloc[ind, 1:] = return_most_common_venues(lf_rest_onehot.iloc[ind, :], lf_rest_onehot.shape[1])

# %%
hf_rest_sorted.insert(1,'Cluster Labels',kmeans_hf.labels_)
lf_rest_sorted.insert(1,'Cluster Labels',kmeans_lf.labels_)

# %%
hf_rest_sorted.head()
# Out:
#        Neighborhood  Cluster Labels 1st Most Common Venue  \
# 0        AVM Studio               0     Indian Restaurant
# 1  Adyar Bus Debot.               0     Indian Restaurant
# 2      Adyar Signal               0     Indian Restaurant
# 3           Alandur               2     Indian Restaurant
# 4          Ambattur               3           Pizza Place
#
#            2nd Most Common Venue 3rd Most Common Venue  \
# 0                    Pizza Place  Fast Food Restaurant
# 1                    Pizza Place  Fast Food Restaurant
# 2                    Pizza Place          Dessert Shop
# 3                Thai Restaurant             BBQ Joint
# 4  Vegetarian / Vegan Restaurant            Food Court
#
#            4th Most Common Venue 5th Most Common Venue  \
# 0  Vegetarian / Vegan Restaurant      Asian Restaurant
# 1               Asian Restaurant        Sandwich Place
# 2           Fast Food Restaurant             Juice Bar
# 3                         Bistro        Breakfast Spot
# 4                      BBQ Joint                Bistro
#
#            6th Most Common Venue      7th Most Common Venue  \
# 0             Italian Restaurant                  BBQ Joint
# 1                      BBQ Joint  Middle Eastern Restaurant
# 2  Vegetarian / Vegan Restaurant           Asian Restaurant
# 3                         Buffet               Burger Joint
# 4                 Breakfast Spot                     Buffet
#
#   8th Most Common Venue  ... 15th Most Common Venue  \
# 0            Restaurant  ...             Food Court
# 1             Juice Bar  ...            Coffee Shop
# 2    Chinese Restaurant  ...         Breakfast Spot
# 3    Chinese Restaurant  ...    Japanese Restaurant
# 4          Burger Joint  ...     Italian Restaurant
#
#       16th Most Common Venue 17th Most Common Venue  \
# 0  Middle Eastern Restaurant           Dessert Shop
# 1    South Indian Restaurant             Restaurant
# 2                     Buffet           Burger Joint
# 3                  Juice Bar       Kebab Restaurant
# 4        Japanese Restaurant              Juice Bar
#
#       18th Most Common Venue     19th Most Common Venue  \
# 0                Coffee Shop         Chinese Restaurant
# 1                 Food Court            Thai Restaurant
# 2                 Restaurant  Middle Eastern Restaurant
# 3  Middle Eastern Restaurant                Pizza Place
# 4           Kebab Restaurant  Middle Eastern Restaurant
#
#   20th Most Common Venue 21th Most Common Venue 22th Most Common Venue  \
# 0           Burger Joint                 Buffet         Breakfast Spot
# 1     Italian Restaurant    Japanese Restaurant       Kebab Restaurant
# 2             Food Court        Thai Restaurant    Japanese Restaurant
# 3             Restaurant         Sandwich Place            Snack Place
# 4             Restaurant         Sandwich Place            Snack Place
#
#     23th Most Common Venue         24th Most Common Venue
# 0                   Bistro                 Sandwich Place
# 1              Snack Place  Vegetarian / Vegan Restaurant
# 2         Kebab Restaurant        South Indian Restaurant
# 3  South Indian Restaurant               Asian Restaurant
# 4  South Indian Restaurant               Asian Restaurant
#
# [5 rows x 26 columns]

# %%
lf_rest_sorted.head()
# Out:
#        Neighborhood  Cluster Labels    1st Most Common Venue  \
# 0  Adyar Bus Debot.               4                    Diner
# 1      Adyar Signal               8  North Indian Restaurant
# 2           Alandur               1                Cafeteria
# 3         Anna Arch              10                     Food
# 4             CIPET               1                Cafeteria
#
#      2nd Most Common Venue     3rd Most Common Venue 4th Most Common Venue  \
# 0               Steakhouse        Seafood Restaurant   American Restaurant
# 1  Comfort Food Restaurant  Mediterranean Restaurant                 Diner
# 2               Steakhouse        Seafood Restaurant   American Restaurant
# 3               Steakhouse        Seafood Restaurant   American Restaurant
# 4               Steakhouse        Seafood Restaurant   American Restaurant
#
#   5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 0     Andhra Restaurant       Bed & Breakfast    Bengali Restaurant
# 1            Steakhouse            Food Truck     Food & Drink Shop
# 2     Andhra Restaurant       Bed & Breakfast    Bengali Restaurant
# 3     Andhra Restaurant       Bed & Breakfast    Bengali Restaurant
# 4     Andhra Restaurant       Bed & Breakfast    Bengali Restaurant
#
#   8th Most Common Venue  ... 23th Most Common Venue  \
# 0         Burrito Place  ...     Mexican Restaurant
# 1                  Food  ...       Malay Restaurant
# 2         Burrito Place  ...     Mexican Restaurant
# 3         Burrito Place  ...     Mexican Restaurant
# 4         Burrito Place  ...     Mexican Restaurant
#
#        24th Most Common Venue           25th Most Common Venue  \
# 0  Modern European Restaurant  Molecular Gastronomy Restaurant
# 1          Mexican Restaurant       Modern European Restaurant
# 2  Modern European Restaurant  Molecular Gastronomy Restaurant
# 3  Modern European Restaurant  Molecular Gastronomy Restaurant
# 4  Modern European Restaurant  Molecular Gastronomy Restaurant
#
#             26th Most Common Venue          27th Most Common Venue  \
# 0   Multicuisine Indian Restaurant         New American Restaurant
# 1  Molecular Gastronomy Restaurant  Multicuisine Indian Restaurant
# 2   Multicuisine Indian Restaurant         New American Restaurant
# 3   Multicuisine Indian Restaurant         New American Restaurant
# 4   Multicuisine Indian Restaurant         New American Restaurant
#
#     28th Most Common Venue 29th Most Common Venue 30th Most Common Venue  \
# 0  North Indian Restaurant  Portuguese Restaurant  Rajasthani Restaurant
# 1  New American Restaurant  Portuguese Restaurant  Rajasthani Restaurant
# 2  North Indian Restaurant  Portuguese Restaurant  Rajasthani Restaurant
# 3  North Indian Restaurant  Portuguese Restaurant  Rajasthani Restaurant
# 4  North Indian Restaurant  Portuguese Restaurant  Rajasthani Restaurant
#
#   31th Most Common Venue 32th Most Common Venue
# 0     Russian Restaurant     African Restaurant
# 1     Russian Restaurant     African Restaurant
# 2     Russian Restaurant     African Restaurant
# 3     Russian Restaurant     African Restaurant
# 4     Russian Restaurant     African Restaurant
#
# [5 rows x 34 columns]

# %% [markdown]
# ## Analysing clusters of high frequency restaurants dataframe

# %% [markdown]
# **High Frequency Restaurant Categories**

# %% [markdown]
# **Cluster 0** - Areas with very high incidence of **Indian Restaurants** , followed by a high incidence of **Pizza Places** and **Chinese restaurants**

# %% [markdown]
# Have a low incidence of **BBQ joints**, **Asian restaurants(excluding chinese)** and **cafe/coffee shops**

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==0,:]
# Out:
#                Neighborhood  Cluster Labels 1st Most Common Venue  \
# 0                AVM Studio               0     Indian Restaurant
# 1          Adyar Bus Debot.               0     Indian Restaurant
# 2              Adyar Signal               0     Indian Restaurant
# 13                    CIPET               0     Indian Restaurant
# 14       CIT Nagar Roundana               0     Indian Restaurant
# ..                      ...             ...                   ...
# 94          Valluvar Kottam               0     Indian Restaurant
# 95               Vani Mahal               0     Indian Restaurant
# 96   Velachery Bus Terminus               0     Indian Restaurant
# 99       Woodlands Drive In               0     Indian Restaurant
# 100                 chetput               0     Indian Restaurant
#
#     2nd Most Common Venue 3rd Most Common Venue  \
# 0             Pizza Place  Fast Food Restaurant
# 1             Pizza Place  Fast Food Restaurant
# 2             Pizza Place          Dessert Shop
# 13       Asian Restaurant            Restaurant
# 14     Italian Restaurant    Chinese Restaurant
# ..                    ...                   ...
# 94     Chinese Restaurant           Coffee Shop
# 95            Coffee Shop            Restaurant
# 96   Fast Food Restaurant            Restaurant
# 99     Chinese Restaurant        Sandwich Place
# 100    Chinese Restaurant           Coffee Shop
#
#              4th Most Common Venue    5th Most Common Venue  \
# 0    Vegetarian / Vegan Restaurant         Asian Restaurant
# 1                 Asian Restaurant           Sandwich Place
# 2             Fast Food Restaurant                Juice Bar
# 13                    Dessert Shop  South Indian Restaurant
# 14            Fast Food Restaurant          Thai Restaurant
# ..                             ...                      ...
# 94                     Pizza Place                BBQ Joint
# 95              Italian Restaurant                BBQ Joint
# 96              Chinese Restaurant              Pizza Place
# 99                     Coffee Shop       Italian Restaurant
# 100                     Restaurant                Juice Bar
#
#              6th Most Common Venue      7th Most Common Venue  \
# 0               Italian Restaurant                  BBQ Joint
# 1                        BBQ Joint  Middle Eastern Restaurant
# 2    Vegetarian / Vegan Restaurant           Asian Restaurant
# 13            Fast Food Restaurant                  BBQ Joint
# 14   Vegetarian / Vegan Restaurant           Asian Restaurant
# ..                             ...                        ...
# 94              Italian Restaurant           Asian Restaurant
# 95              Chinese Restaurant                Pizza Place
# 96              Italian Restaurant                Coffee Shop
# 99                      Restaurant                Pizza Place
# 100           Fast Food Restaurant           Asian Restaurant
#
#              8th Most Common Venue    9th Most Common Venue  \
# 0                       Restaurant  South Indian Restaurant
# 1                        Juice Bar           Breakfast Spot
# 2               Chinese Restaurant           Sandwich Place
# 13                          Bistro           Breakfast Spot
# 14         South Indian Restaurant               Restaurant
# ..                             ...                      ...
# 94         South Indian Restaurant               Restaurant
# 95                    Dessert Shop     Fast Food Restaurant
# 96   Vegetarian / Vegan Restaurant              Snack Place
# 99       Middle Eastern Restaurant                Juice Bar
# 100                    Snack Place           Sandwich Place
#
#             10th Most Common Venue 11th Most Common Venue  \
# 0                      Snack Place              Juice Bar
# 1               Chinese Restaurant           Dessert Shop
# 2               Italian Restaurant            Snack Place
# 13                          Buffet           Burger Joint
# 14                  Sandwich Place            Snack Place
# ..                             ...                    ...
# 94                  Sandwich Place           Dessert Shop
# 95   Vegetarian / Vegan Restaurant              Juice Bar
# 96                Kebab Restaurant              Juice Bar
# 99                       BBQ Joint        Thai Restaurant
# 100      Middle Eastern Restaurant              BBQ Joint
#
#             12th Most Common Venue     13th Most Common Venue  \
# 0              Japanese Restaurant           Kebab Restaurant
# 1                           Bistro                     Buffet
# 2                      Coffee Shop                  BBQ Joint
# 13              Chinese Restaurant                Coffee Shop
# 14                       BBQ Joint                     Bistro
# ..                             ...                        ...
# 94             Japanese Restaurant            Thai Restaurant
# 95                  Sandwich Place    South Indian Restaurant
# 96             Japanese Restaurant  Middle Eastern Restaurant
# 99   Vegetarian / Vegan Restaurant    South Indian Restaurant
# 100                         Bistro             Breakfast Spot
#
#     14th Most Common Venue 15th Most Common Venue     16th Most Common Venue  \
# 0          Thai Restaurant             Food Court  Middle Eastern Restaurant
# 1             Burger Joint            Coffee Shop    South Indian Restaurant
# 2                   Bistro         Breakfast Spot                     Buffet
# 13              Food Court            Snack Place            Thai Restaurant
# 14          Breakfast Spot                 Buffet               Burger Joint
# ..                     ...                    ...                        ...
# 94    Fast Food Restaurant           Burger Joint                     Bistro
# 95     Japanese Restaurant        Thai Restaurant                 Food Court
# 96         Thai Restaurant             Food Court             Sandwich Place
# 99        Asian Restaurant    Japanese Restaurant                 Food Court
# 100                 Buffet           Burger Joint    South Indian Restaurant
#
#     17th Most Common Venue     18th Most Common Venue  \
# 0             Dessert Shop                Coffee Shop
# 1               Restaurant                 Food Court
# 2             Burger Joint                 Restaurant
# 13      Italian Restaurant        Japanese Restaurant
# 14             Pizza Place                Coffee Shop
# ..                     ...                        ...
# 94          Breakfast Spot                     Buffet
# 95        Kebab Restaurant  Middle Eastern Restaurant
# 96            Dessert Shop    South Indian Restaurant
# 99    Fast Food Restaurant               Dessert Shop
# 100           Dessert Shop           Kebab Restaurant
#
#         19th Most Common Venue 20th Most Common Venue  \
# 0           Chinese Restaurant           Burger Joint
# 1              Thai Restaurant     Italian Restaurant
# 2    Middle Eastern Restaurant             Food Court
# 13                   Juice Bar       Kebab Restaurant
# 14   Middle Eastern Restaurant             Food Court
# ..                         ...                    ...
# 94   Middle Eastern Restaurant            Snack Place
# 95                 Snack Place           Burger Joint
# 96                Burger Joint                 Buffet
# 99            Kebab Restaurant            Snack Place
# 100                 Food Court        Thai Restaurant
#
#         21th Most Common Venue 22th Most Common Venue 23th Most Common Venue  \
# 0                       Buffet         Breakfast Spot                 Bistro
# 1          Japanese Restaurant       Kebab Restaurant            Snack Place
# 2              Thai Restaurant    Japanese Restaurant       Kebab Restaurant
# 13   Middle Eastern Restaurant            Pizza Place         Sandwich Place
# 14         Japanese Restaurant              Juice Bar       Kebab Restaurant
# ..                         ...                    ...                    ...
# 94            Kebab Restaurant             Food Court              Juice Bar
# 95                      Buffet         Breakfast Spot                 Bistro
# 96              Breakfast Spot                 Bistro              BBQ Joint
# 99                Burger Joint                 Buffet         Breakfast Spot
# 100         Italian Restaurant    Japanese Restaurant            Pizza Place
#
#             24th Most Common Venue
# 0                   Sandwich Place
# 1    Vegetarian / Vegan Restaurant
# 2          South Indian Restaurant
# 13   Vegetarian / Vegan Restaurant
# 14                    Dessert Shop
# ..                             ...
# 94   Vegetarian / Vegan Restaurant
# 95                Asian Restaurant
# 96                Asian Restaurant
# 99                          Bistro
# 100  Vegetarian / Vegan Restaurant
#
# [38 rows x 26 columns]

# %% [markdown]
# **Since only one restaurant falls under this category, we drop this cluster since it isnt statistially significant**

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==4,:]
# Out:
#     Neighborhood  Cluster Labels 1st Most Common Venue 2nd Most Common Venue  \
# 89  Tiruvottiyur               4      Asian Restaurant       Thai Restaurant
#
#    3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 89             BBQ Joint                Bistro        Breakfast Spot
#
#    6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 89                Buffet          Burger Joint    Chinese Restaurant
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 89           Coffee Shop           Dessert Shop   Fast Food Restaurant
#
#    12th Most Common Venue         13th Most Common Venue  \
# 89             Food Court  Vegetarian / Vegan Restaurant
#
#    14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 89     Italian Restaurant    Japanese Restaurant              Juice Bar
#
#    17th Most Common Venue     18th Most Common Venue 19th Most Common Venue  \
# 89       Kebab Restaurant  Middle Eastern Restaurant            Pizza Place
#
#    20th Most Common Venue 21th Most Common Venue 22th Most Common Venue  \
# 89             Restaurant         Sandwich Place            Snack Place
#
#      23th Most Common Venue 24th Most Common Venue
# 89  South Indian Restaurant      Indian Restaurant

# %% [markdown]
# **Cluster 5** - Very high incidence of **Indian (both North and South) restaurants** as well as a high incidence of **Chinese restaurants and BBQ joints**

# %% [markdown]
# Low incidence of **Non chinese Asian restaurants**, **Burger and buffet joints** and **general snack places and sandwich shops**

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==5,:]
# Out:
#                   Neighborhood  Cluster Labels 1st Most Common Venue  \
# 5                    Anna Arch               5  Fast Food Restaurant
# 6          Anna Nagar Roundana               5     Indian Restaurant
# 7     Anna Nagar West Terminus               5     Indian Restaurant
# 9     Anna University Entrance               5           Snack Place
# 11              Ayyappa Temple               5     Indian Restaurant
# ..                         ...             ...                   ...
# 86  Thiruvanmiyur Bus Terminus               5     Indian Restaurant
# 87      Thiruvanmiyur Junction               5     Indian Restaurant
# 88                  Tidel Park               5     Indian Restaurant
# 92  Triplicane Railway Station               5     Indian Restaurant
# 93           Vadapalani Signal               5     Indian Restaurant
#
#         2nd Most Common Venue          3rd Most Common Venue  \
# 5                 Pizza Place  Vegetarian / Vegan Restaurant
# 6          Chinese Restaurant                     Restaurant
# 7        Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 9          Chinese Restaurant                      Juice Bar
# 11                 Restaurant                      BBQ Joint
# ..                        ...                            ...
# 86                  BBQ Joint                         Bistro
# 87                  BBQ Joint                         Bistro
# 88                 Food Court                 Sandwich Place
# 92  Middle Eastern Restaurant                      Juice Bar
# 93                Pizza Place                     Restaurant
#
#             4th Most Common Venue          5th Most Common Venue  \
# 5                       Juice Bar                      BBQ Joint
# 6                     Coffee Shop  Vegetarian / Vegan Restaurant
# 7                       BBQ Joint                    Pizza Place
# 9   Vegetarian / Vegan Restaurant                     Food Court
# 11                      Juice Bar  Vegetarian / Vegan Restaurant
# ..                            ...                            ...
# 86                 Sandwich Place                    Pizza Place
# 87                 Sandwich Place                    Pizza Place
# 88                         Bistro                 Breakfast Spot
# 92  Vegetarian / Vegan Restaurant                 Sandwich Place
# 93                    Coffee Shop           Fast Food Restaurant
#
#    6th Most Common Venue      7th Most Common Venue  \
# 5     Chinese Restaurant                Coffee Shop
# 6   Fast Food Restaurant  Middle Eastern Restaurant
# 7     Italian Restaurant                Snack Place
# 9              BBQ Joint                     Bistro
# 11      Asian Restaurant    South Indian Restaurant
# ..                   ...                        ...
# 86          Burger Joint                  Juice Bar
# 87          Burger Joint                  Juice Bar
# 88    Chinese Restaurant       Fast Food Restaurant
# 92            Food Court                Coffee Shop
# 93      Asian Restaurant    South Indian Restaurant
#
#             8th Most Common Venue    9th Most Common Venue  \
# 5               Indian Restaurant  South Indian Restaurant
# 6                       Juice Bar              Pizza Place
# 7                    Dessert Shop                   Bistro
# 9                  Breakfast Spot                   Buffet
# 11                   Dessert Shop                   Bistro
# ..                            ...                      ...
# 86             Chinese Restaurant     Fast Food Restaurant
# 87             Chinese Restaurant               Food Court
# 88  Vegetarian / Vegan Restaurant              Pizza Place
# 92           Fast Food Restaurant              Pizza Place
# 93                   Dessert Shop       Italian Restaurant
#
#    10th Most Common Venue     11th Most Common Venue  \
# 5        Kebab Restaurant  Middle Eastern Restaurant
# 6               BBQ Joint                     Bistro
# 7          Breakfast Spot                     Buffet
# 9            Burger Joint                Coffee Shop
# 11         Breakfast Spot                     Buffet
# ..                    ...                        ...
# 86         Breakfast Spot                     Buffet
# 87   Fast Food Restaurant             Breakfast Spot
# 88            Snack Place           Kebab Restaurant
# 92       Kebab Restaurant    South Indian Restaurant
# 93              BBQ Joint         Chinese Restaurant
#
#            12th Most Common Venue   13th Most Common Venue  \
# 5             Japanese Restaurant       Italian Restaurant
# 6                    Burger Joint  South Indian Restaurant
# 7                    Burger Joint       Chinese Restaurant
# 9                    Dessert Shop     Fast Food Restaurant
# 11                   Burger Joint       Chinese Restaurant
# ..                            ...                      ...
# 86                    Coffee Shop             Dessert Shop
# 87                         Buffet              Coffee Shop
# 88                      Juice Bar      Japanese Restaurant
# 92            Japanese Restaurant       Italian Restaurant
# 93  Vegetarian / Vegan Restaurant                Juice Bar
#
#            14th Most Common Venue         15th Most Common Venue  \
# 5                 Thai Restaurant                     Food Court
# 6                     Snack Place                 Sandwich Place
# 7                     Coffee Shop                     Food Court
# 9               Indian Restaurant                Thai Restaurant
# 11                    Coffee Shop                 Sandwich Place
# ..                            ...                            ...
# 86  Vegetarian / Vegan Restaurant                     Food Court
# 87                   Dessert Shop  Vegetarian / Vegan Restaurant
# 88             Italian Restaurant                Thai Restaurant
# 92                Thai Restaurant                    Snack Place
# 93                Thai Restaurant                     Food Court
#
#        16th Most Common Venue     17th Most Common Venue  \
# 5                  Restaurant               Dessert Shop
# 6            Asian Restaurant               Dessert Shop
# 7     South Indian Restaurant             Sandwich Place
# 9          Italian Restaurant        Japanese Restaurant
# 11                Pizza Place                 Food Court
# ..                        ...                        ...
# 86            Thai Restaurant         Italian Restaurant
# 87            Thai Restaurant         Italian Restaurant
# 88  Middle Eastern Restaurant               Dessert Shop
# 92                 Restaurant               Dessert Shop
# 93                Snack Place  Middle Eastern Restaurant
#
#    18th Most Common Venue     19th Most Common Venue  \
# 5          Sandwich Place                Snack Place
# 6              Food Court            Thai Restaurant
# 7         Thai Restaurant        Japanese Restaurant
# 9        Kebab Restaurant  Middle Eastern Restaurant
# 11        Thai Restaurant         Italian Restaurant
# ..                    ...                        ...
# 86    Japanese Restaurant           Kebab Restaurant
# 87    Japanese Restaurant           Kebab Restaurant
# 88            Coffee Shop                 Restaurant
# 92     Chinese Restaurant               Burger Joint
# 93    Japanese Restaurant               Burger Joint
#
#        20th Most Common Venue 21th Most Common Venue  \
# 5                Burger Joint                 Buffet
# 6          Italian Restaurant                 Buffet
# 7                   Juice Bar       Kebab Restaurant
# 9                 Pizza Place             Restaurant
# 11        Japanese Restaurant            Snack Place
# ..                        ...                    ...
# 86  Middle Eastern Restaurant             Restaurant
# 87  Middle Eastern Restaurant             Restaurant
# 88               Burger Joint                 Buffet
# 92                     Buffet         Breakfast Spot
# 93                     Buffet         Breakfast Spot
#
#        22th Most Common Venue     23th Most Common Venue  \
# 5              Breakfast Spot                     Bistro
# 6              Breakfast Spot        Japanese Restaurant
# 7   Middle Eastern Restaurant                 Restaurant
# 9              Sandwich Place    South Indian Restaurant
# 11           Kebab Restaurant  Middle Eastern Restaurant
# ..                        ...                        ...
# 86                Snack Place    South Indian Restaurant
# 87                Snack Place    South Indian Restaurant
# 88    South Indian Restaurant                  BBQ Joint
# 92                     Bistro                  BBQ Joint
# 93                     Bistro           Kebab Restaurant
#
#    24th Most Common Venue
# 5        Asian Restaurant
# 6        Kebab Restaurant
# 7        Asian Restaurant
# 9        Asian Restaurant
# 11   Fast Food Restaurant
# ..                    ...
# 86       Asian Restaurant
# 87       Asian Restaurant
# 88       Asian Restaurant
# 92       Asian Restaurant
# 93         Sandwich Place
#
# [39 rows x 26 columns]

# %% [markdown]
# **Cluster 2** - Very high incidence of **Indian Restaurants** followed by a high incidence of **Dessert shops and Breakfast shops**

# %% [markdown]
# Low incidence of **South indian**, **snacking and sandwich places**, **Pizza places**, **fast food restaurants** and **Italian and thai restaurants**

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==2,:]
# Out:
#           Neighborhood  Cluster Labels 1st Most Common Venue  \
# 3              Alandur               2     Indian Restaurant
# 8          Anna Statue               2     Indian Restaurant
# 10               Avadi               2     Indian Restaurant
# 21        Chintadripet               2     Indian Restaurant
# 40  Kathipara Junction               2     Indian Restaurant
# 44         Le Meridian               2     Indian Restaurant
# 64    Parrys Bus Stand               2     Indian Restaurant
# 70           Royapuram               2     Indian Restaurant
# 91          Triplicane               2     Indian Restaurant
# 97         Villivakkam               2     Indian Restaurant
#
#         2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 3             Thai Restaurant             BBQ Joint                Bistro
# 8                Dessert Shop       Thai Restaurant             BBQ Joint
# 10            Thai Restaurant             BBQ Joint                Bistro
# 21               Dessert Shop       Thai Restaurant             BBQ Joint
# 40             Breakfast Spot           Pizza Place            Food Court
# 44             Breakfast Spot           Pizza Place            Food Court
# 64                 Restaurant            Food Court             BBQ Joint
# 70            Thai Restaurant             BBQ Joint                Bistro
# 91  Middle Eastern Restaurant        Breakfast Spot          Dessert Shop
# 97            Thai Restaurant             BBQ Joint                Bistro
#
#             5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 3                  Breakfast Spot                Buffet          Burger Joint
# 8                          Bistro        Breakfast Spot                Buffet
# 10                 Breakfast Spot                Buffet          Burger Joint
# 21                         Bistro        Breakfast Spot                Buffet
# 40                      BBQ Joint                Bistro                Buffet
# 44                      BBQ Joint                Bistro                Buffet
# 64                         Bistro        Breakfast Spot                Buffet
# 70                 Breakfast Spot                Buffet          Burger Joint
# 91  Vegetarian / Vegan Restaurant            Restaurant           Snack Place
# 97                 Breakfast Spot                Buffet          Burger Joint
#
#    8th Most Common Venue 9th Most Common Venue   10th Most Common Venue  \
# 3     Chinese Restaurant           Coffee Shop             Dessert Shop
# 8           Burger Joint    Chinese Restaurant              Coffee Shop
# 10    Chinese Restaurant           Coffee Shop             Dessert Shop
# 21          Burger Joint    Chinese Restaurant              Coffee Shop
# 40          Burger Joint    Chinese Restaurant              Coffee Shop
# 44          Burger Joint    Chinese Restaurant              Coffee Shop
# 64          Burger Joint    Chinese Restaurant              Coffee Shop
# 70    Chinese Restaurant           Coffee Shop             Dessert Shop
# 91             BBQ Joint                Bistro  South Indian Restaurant
# 97    Chinese Restaurant           Coffee Shop             Dessert Shop
#
#    11th Most Common Venue 12th Most Common Venue  \
# 3    Fast Food Restaurant             Food Court
# 8    Fast Food Restaurant             Food Court
# 10   Fast Food Restaurant             Food Court
# 21   Fast Food Restaurant             Food Court
# 40           Dessert Shop   Fast Food Restaurant
# 44           Dessert Shop   Fast Food Restaurant
# 64           Dessert Shop   Fast Food Restaurant
# 70   Fast Food Restaurant             Food Court
# 91                 Buffet           Burger Joint
# 97   Fast Food Restaurant             Food Court
#
#            13th Most Common Venue 14th Most Common Venue  \
# 3   Vegetarian / Vegan Restaurant     Italian Restaurant
# 8   Vegetarian / Vegan Restaurant     Italian Restaurant
# 10  Vegetarian / Vegan Restaurant     Italian Restaurant
# 21  Vegetarian / Vegan Restaurant     Italian Restaurant
# 40  Vegetarian / Vegan Restaurant        Thai Restaurant
# 44  Vegetarian / Vegan Restaurant        Thai Restaurant
# 64  Vegetarian / Vegan Restaurant        Thai Restaurant
# 70  Vegetarian / Vegan Restaurant     Italian Restaurant
# 91             Chinese Restaurant            Coffee Shop
# 97  Vegetarian / Vegan Restaurant     Italian Restaurant
#
#    15th Most Common Venue 16th Most Common Venue 17th Most Common Venue  \
# 3     Japanese Restaurant              Juice Bar       Kebab Restaurant
# 8     Japanese Restaurant              Juice Bar       Kebab Restaurant
# 10    Japanese Restaurant              Juice Bar       Kebab Restaurant
# 21    Japanese Restaurant              Juice Bar       Kebab Restaurant
# 40     Italian Restaurant    Japanese Restaurant              Juice Bar
# 44     Italian Restaurant    Japanese Restaurant              Juice Bar
# 64     Italian Restaurant    Japanese Restaurant              Juice Bar
# 70    Japanese Restaurant              Juice Bar       Kebab Restaurant
# 91   Fast Food Restaurant            Pizza Place             Food Court
# 97    Japanese Restaurant              Juice Bar       Kebab Restaurant
#
#        18th Most Common Venue     19th Most Common Venue  \
# 3   Middle Eastern Restaurant                Pizza Place
# 8   Middle Eastern Restaurant                Pizza Place
# 10  Middle Eastern Restaurant                Pizza Place
# 21  Middle Eastern Restaurant                Pizza Place
# 40           Kebab Restaurant  Middle Eastern Restaurant
# 44           Kebab Restaurant  Middle Eastern Restaurant
# 64           Kebab Restaurant  Middle Eastern Restaurant
# 70  Middle Eastern Restaurant                Pizza Place
# 91            Thai Restaurant         Italian Restaurant
# 97  Middle Eastern Restaurant                Pizza Place
#
#    20th Most Common Venue 21th Most Common Venue 22th Most Common Venue  \
# 3              Restaurant         Sandwich Place            Snack Place
# 8              Restaurant         Sandwich Place            Snack Place
# 10             Restaurant         Sandwich Place            Snack Place
# 21             Restaurant         Sandwich Place            Snack Place
# 40             Restaurant         Sandwich Place            Snack Place
# 44             Restaurant         Sandwich Place            Snack Place
# 64            Pizza Place         Sandwich Place            Snack Place
# 70             Restaurant         Sandwich Place            Snack Place
# 91    Japanese Restaurant              Juice Bar       Kebab Restaurant
# 97             Restaurant         Sandwich Place            Snack Place
#
#      23th Most Common Venue 24th Most Common Venue
# 3   South Indian Restaurant       Asian Restaurant
# 8   South Indian Restaurant       Asian Restaurant
# 10  South Indian Restaurant       Asian Restaurant
# 21  South Indian Restaurant       Asian Restaurant
# 40  South Indian Restaurant       Asian Restaurant
# 44  South Indian Restaurant       Asian Restaurant
# 64  South Indian Restaurant       Asian Restaurant
# 70  South Indian Restaurant       Asian Restaurant
# 91           Sandwich Place       Asian Restaurant
# 97  South Indian Restaurant       Asian Restaurant

# %% [markdown]
# **Cluster 6** - A very high incidence of **Vegetarian and Thai restaurants** and a high incidence of **BBQ and bistro joints**

# %% [markdown]
# Low incidence of **Pizza places**, **snacking places**, and **exotic cuisines(apart from thai)**

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==6,:]
# Out:
#    Neighborhood  Cluster Labels          1st Most Common Venue  \
# 42   Korukkupet               6  Vegetarian / Vegan Restaurant
# 68  Poonamallee               6  Vegetarian / Vegan Restaurant
# 78   TVS Signal               6  Vegetarian / Vegan Restaurant
# 90   Tondiarpet               6  Vegetarian / Vegan Restaurant
#
#    2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 42       Thai Restaurant             BBQ Joint                Bistro
# 68       Thai Restaurant             BBQ Joint                Bistro
# 78       Thai Restaurant             BBQ Joint                Bistro
# 90       Thai Restaurant             BBQ Joint                Bistro
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 42        Breakfast Spot                Buffet          Burger Joint
# 68        Breakfast Spot                Buffet          Burger Joint
# 78        Breakfast Spot                Buffet          Burger Joint
# 90        Breakfast Spot                Buffet          Burger Joint
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 42    Chinese Restaurant           Coffee Shop           Dessert Shop
# 68    Chinese Restaurant           Coffee Shop           Dessert Shop
# 78    Chinese Restaurant           Coffee Shop           Dessert Shop
# 90    Chinese Restaurant           Coffee Shop           Dessert Shop
#
#    11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 42   Fast Food Restaurant             Food Court      Indian Restaurant
# 68   Fast Food Restaurant             Food Court      Indian Restaurant
# 78   Fast Food Restaurant             Food Court      Indian Restaurant
# 90   Fast Food Restaurant             Food Court      Indian Restaurant
#
#    14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 42     Italian Restaurant    Japanese Restaurant              Juice Bar
# 68     Italian Restaurant    Japanese Restaurant              Juice Bar
# 78     Italian Restaurant    Japanese Restaurant              Juice Bar
# 90     Italian Restaurant    Japanese Restaurant              Juice Bar
#
#    17th Most Common Venue     18th Most Common Venue 19th Most Common Venue  \
# 42       Kebab Restaurant  Middle Eastern Restaurant            Pizza Place
# 68       Kebab Restaurant  Middle Eastern Restaurant            Pizza Place
# 78       Kebab Restaurant  Middle Eastern Restaurant            Pizza Place
# 90       Kebab Restaurant  Middle Eastern Restaurant            Pizza Place
#
#    20th Most Common Venue 21th Most Common Venue 22th Most Common Venue  \
# 42             Restaurant         Sandwich Place            Snack Place
# 68             Restaurant         Sandwich Place            Snack Place
# 78             Restaurant         Sandwich Place            Snack Place
# 90             Restaurant         Sandwich Place            Snack Place
#
#      23th Most Common Venue 24th Most Common Venue
# 42  South Indian Restaurant       Asian Restaurant
# 68  South Indian Restaurant       Asian Restaurant
# 78  South Indian Restaurant       Asian Restaurant
# 90  South Indian Restaurant       Asian Restaurant

# %% [markdown]
# **Cluster 3** - Very high incidence of **Pizza places** and a high incidence of **Vegan restaurants and BBQ joints**

# %% [markdown]
# A small sample so difficult to gauge the lacking parameters

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==3,:]
# Out:
#     Neighborhood  Cluster Labels 1st Most Common Venue  \
# 4       Ambattur               3           Pizza Place
# 12  Basin Bridge               3           Pizza Place
# 98   Vyasar Padi               3           Pizza Place
#
#             2nd Most Common Venue 3rd Most Common Venue 4th Most Common Venue  \
# 4   Vegetarian / Vegan Restaurant            Food Court             BBQ Joint
# 12  Vegetarian / Vegan Restaurant            Food Court             BBQ Joint
# 98  Vegetarian / Vegan Restaurant            Food Court             BBQ Joint
#
#    5th Most Common Venue 6th Most Common Venue 7th Most Common Venue  \
# 4                 Bistro        Breakfast Spot                Buffet
# 12                Bistro        Breakfast Spot                Buffet
# 98                Bistro        Breakfast Spot                Buffet
#
#    8th Most Common Venue 9th Most Common Venue 10th Most Common Venue  \
# 4           Burger Joint    Chinese Restaurant            Coffee Shop
# 12          Burger Joint    Chinese Restaurant            Coffee Shop
# 98          Burger Joint    Chinese Restaurant            Coffee Shop
#
#    11th Most Common Venue 12th Most Common Venue 13th Most Common Venue  \
# 4            Dessert Shop   Fast Food Restaurant      Indian Restaurant
# 12           Dessert Shop   Fast Food Restaurant      Indian Restaurant
# 98           Dessert Shop   Fast Food Restaurant      Indian Restaurant
#
#    14th Most Common Venue 15th Most Common Venue 16th Most Common Venue  \
# 4         Thai Restaurant     Italian Restaurant    Japanese Restaurant
# 12        Thai Restaurant     Italian Restaurant    Japanese Restaurant
# 98        Thai Restaurant     Italian Restaurant    Japanese Restaurant
#
#    17th Most Common Venue 18th Most Common Venue     19th Most Common Venue  \
# 4               Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
# 12              Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
# 98              Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
#
#    20th Most Common Venue 21th Most Common Venue 22th Most Common Venue  \
# 4              Restaurant         Sandwich Place            Snack Place
# 12             Restaurant         Sandwich Place            Snack Place
# 98             Restaurant         Sandwich Place            Snack Place
#
#      23th Most Common Venue 24th Most Common Venue
# 4   South Indian Restaurant       Asian Restaurant
# 12  South Indian Restaurant       Asian Restaurant
# 98  South Indian Restaurant       Asian Restaurant

# %% [markdown]
# **Cluster 1** - Very high incidence of **Fast food restaurants** followed by a high incidence of **Vegan/Vegetarian restaurants**

# %% [markdown]
# Very lacking in any form of exotc cuisine (italian, middle easter, japanese) and is one of few clusters showing a lack in **Indian Restaurants** which primarily implies north indian restaurants

# %%
hf_rest_sorted.loc[hf_rest_sorted['Cluster Labels']==1,:]
# Out:
#                             Neighborhood  Cluster Labels  \
# 16                       Chennai Airport               1
# 18  Chennai Mofussil Bus Terminas (CMBT)               1
# 43           Koyambedu Omni Bus Terminus               1
# 45                           Light House               1
# 47                         MIOT Hospital               1
# 53                           Minambakkam               1
#
#             1st Most Common Venue          2nd Most Common Venue  \
# 16           Fast Food Restaurant        South Indian Restaurant
# 18           Fast Food Restaurant  Vegetarian / Vegan Restaurant
# 43  Vegetarian / Vegan Restaurant           Fast Food Restaurant
# 45           Fast Food Restaurant                    Coffee Shop
# 47           Fast Food Restaurant              Indian Restaurant
# 53           Fast Food Restaurant  Vegetarian / Vegan Restaurant
#
#       3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 16              Pizza Place           Coffee Shop          Dessert Shop
# 18       Chinese Restaurant            Food Court       Thai Restaurant
# 43               Food Court       Thai Restaurant             BBQ Joint
# 45        Indian Restaurant        Sandwich Place           Pizza Place
# 47  South Indian Restaurant            Food Court             BBQ Joint
# 53          Thai Restaurant             BBQ Joint                Bistro
#
#             6th Most Common Venue 7th Most Common Venue 8th Most Common Venue  \
# 16  Vegetarian / Vegan Restaurant            Food Court             BBQ Joint
# 18                      BBQ Joint                Bistro        Breakfast Spot
# 43                         Bistro        Breakfast Spot                Buffet
# 45             Chinese Restaurant    Italian Restaurant             BBQ Joint
# 47                         Bistro        Breakfast Spot                Buffet
# 53                 Breakfast Spot                Buffet          Burger Joint
#
#    9th Most Common Venue 10th Most Common Venue 11th Most Common Venue  \
# 16                Bistro         Breakfast Spot                 Buffet
# 18                Buffet           Burger Joint            Coffee Shop
# 43          Burger Joint     Chinese Restaurant            Coffee Shop
# 45                Bistro         Breakfast Spot                 Buffet
# 47          Burger Joint     Chinese Restaurant            Coffee Shop
# 53    Chinese Restaurant            Coffee Shop           Dessert Shop
#
#    12th Most Common Venue         13th Most Common Venue  \
# 16           Burger Joint             Chinese Restaurant
# 18           Dessert Shop              Indian Restaurant
# 43           Dessert Shop              Indian Restaurant
# 45           Burger Joint                   Dessert Shop
# 47           Dessert Shop  Vegetarian / Vegan Restaurant
# 53             Food Court              Indian Restaurant
#
#            14th Most Common Venue 15th Most Common Venue  \
# 16              Indian Restaurant        Thai Restaurant
# 18             Italian Restaurant    Japanese Restaurant
# 43             Italian Restaurant    Japanese Restaurant
# 45  Vegetarian / Vegan Restaurant             Food Court
# 47                Thai Restaurant     Italian Restaurant
# 53             Italian Restaurant    Japanese Restaurant
#
#    16th Most Common Venue 17th Most Common Venue     18th Most Common Venue  \
# 16     Italian Restaurant    Japanese Restaurant                  Juice Bar
# 18              Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
# 43              Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
# 45        Thai Restaurant    Japanese Restaurant                  Juice Bar
# 47    Japanese Restaurant              Juice Bar           Kebab Restaurant
# 53              Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
#
#        19th Most Common Venue     20th Most Common Venue  \
# 16           Kebab Restaurant  Middle Eastern Restaurant
# 18                Pizza Place                 Restaurant
# 43                Pizza Place                 Restaurant
# 45           Kebab Restaurant  Middle Eastern Restaurant
# 47  Middle Eastern Restaurant                Pizza Place
# 53                Pizza Place                 Restaurant
#
#    21th Most Common Venue 22th Most Common Venue   23th Most Common Venue  \
# 16             Restaurant         Sandwich Place              Snack Place
# 18         Sandwich Place            Snack Place  South Indian Restaurant
# 43         Sandwich Place            Snack Place  South Indian Restaurant
# 45             Restaurant            Snack Place  South Indian Restaurant
# 47             Restaurant         Sandwich Place              Snack Place
# 53         Sandwich Place            Snack Place  South Indian Restaurant
#
#    24th Most Common Venue
# 16       Asian Restaurant
# 18       Asian Restaurant
# 43       Asian Restaurant
# 45       Asian Restaurant
# 47       Asian Restaurant
# 53       Asian Restaurant

# %% [markdown]
# ### Cluster Summary

# %%
cluster_labels=[5,3,6,1,4,0,2]
high_incidence=["Indian followed by Chinese and BBQ joints",
                "Pizza place followed by vegetarian & BBQ joints",
                "Vegetarian & Thai followed by Vegan & BBQ joints",
                "Fast food restaurants followed by vegan restaurants",
                "Not statistically significant",
                "Indian followed by Pizza & Chinese",
                "Indian followed by Dessert & Breakfast shops"]
low_incidence=["Non chinese asian, burger, buffet, snacking",
               "Exotic restaurants",
               "Pizza places, snacking places & exotic cuisines",
               "Indian restaurants followed by exotic cuisines",
               "Not statistically significant",
               "BBQ, asian, Cafe & coffe shops",
               "South Indian, Snacking & Sandwich places, Pizza places, fast food restaurants & Italian & thai restaurants"]
dataset={'Cluster Labels':cluster_labels,'High Frequency locations':high_incidence,'Low Frequency Locations':low_incidence}

# %%
hf_restaurant_classification=pd.DataFrame(data=dataset)
hf_restaurant_classification.sort_values(by=['Cluster Labels'],inplace=True)
hf_restaurant_classification.reset_index(drop=True,inplace=True)
hf_restaurant_classification
# Out:
#    Cluster Labels                             High Frequency locations  \
# 0               0                   Indian followed by Pizza & Chinese
# 1               1  Fast food restaurants followed by vegan restaurants
# 2               2         Indian followed by Dessert & Breakfast shops
# 3               3      Pizza place followed by vegetarian & BBQ joints
# 4               4                        Not statistically significant
# 5               5            Indian followed by Chinese and BBQ joints
# 6               6     Vegetarian & Thai followed by Vegan & BBQ joints
#
#                                                                                       Low Frequency Locations
# 0                                                                              BBQ, asian, Cafe & coffe shops
# 1                                                              Indian restaurants followed by exotic cuisines
# 2  South Indian, Snacking & Sandwich places, Pizza places, fast food restaurants & Italian & thai restaurants
# 3                                                                                          Exotic restaurants
# 4                                                                               Not statistically significant
# 5                                                                 Non chinese asian, burger, buffet, snacking
# 6                                                             Pizza places, snacking places & exotic cuisines

# %% [markdown]
# **Note:- The distance between the different locations have not been found here as its primary goal is to provide the various categories and their distributions**

# %% [markdown]
# **However, the a function has been included below to determine the distance of a location from the city centre and can be used easily to gauge the relative accessibilitiy of each neighborhood while taking decisions**

# %%
from math import sin,cos,atan2,pi,sqrt
def get_distance(lat1,lng1,lat2,lng2):
    p=pi/180
    del_lat=(lat2-lat1)*p
    del_lng=(lng2-lng1)*p
    lat1*=p
    lat2*=p
    R=6371 ##in kms
    
    a=(((sin(del_lat/2))**2)+(cos(lat1)*cos(lat2))*((sin(del_lng/2))**2))
    c=2*(atan2(sqrt(a),sqrt(1-a)))
    d=R*c
    return d

# %%
print("{} kms".format(get_distance(12.997222,80.256944,13.0801721,80.2838331)))
# Out:
# 9.6726428077056 kms

# %% [markdown]
# **This can be used as a filter**

# %% [markdown]
# **The user can specify a radius and by adding the distane parameter to the dataframe containing the cluster information, we can use groupby to get the analysis of the neighborhoods within radius**

# %%
cluster_df=pd.merge(df,hf_rest_sorted,on='Neighborhood')
cluster_df.head()
# Out:
#        Neighborhood   latitude  longitude  Cluster Labels  \
# 0  Adyar Bus Debot.  12.997222  80.256944               0
# 1      Adyar Signal  13.006389  80.257500               0
# 2           Alandur  13.007778  80.209722               2
# 3          Ambattur  13.110000  80.170000               3
# 4         Anna Arch  13.074444  80.218333               5
#
#   1st Most Common Venue          2nd Most Common Venue  \
# 0     Indian Restaurant                    Pizza Place
# 1     Indian Restaurant                    Pizza Place
# 2     Indian Restaurant                Thai Restaurant
# 3           Pizza Place  Vegetarian / Vegan Restaurant
# 4  Fast Food Restaurant                    Pizza Place
#
#            3rd Most Common Venue 4th Most Common Venue 5th Most Common Venue  \
# 0           Fast Food Restaurant      Asian Restaurant        Sandwich Place
# 1                   Dessert Shop  Fast Food Restaurant             Juice Bar
# 2                      BBQ Joint                Bistro        Breakfast Spot
# 3                     Food Court             BBQ Joint                Bistro
# 4  Vegetarian / Vegan Restaurant             Juice Bar             BBQ Joint
#
#            6th Most Common Venue  ... 15th Most Common Venue  \
# 0                      BBQ Joint  ...            Coffee Shop
# 1  Vegetarian / Vegan Restaurant  ...         Breakfast Spot
# 2                         Buffet  ...    Japanese Restaurant
# 3                 Breakfast Spot  ...     Italian Restaurant
# 4             Chinese Restaurant  ...             Food Court
#
#     16th Most Common Venue 17th Most Common Venue     18th Most Common Venue  \
# 0  South Indian Restaurant             Restaurant                 Food Court
# 1                   Buffet           Burger Joint                 Restaurant
# 2                Juice Bar       Kebab Restaurant  Middle Eastern Restaurant
# 3      Japanese Restaurant              Juice Bar           Kebab Restaurant
# 4               Restaurant           Dessert Shop             Sandwich Place
#
#       19th Most Common Venue 20th Most Common Venue 21th Most Common Venue  \
# 0            Thai Restaurant     Italian Restaurant    Japanese Restaurant
# 1  Middle Eastern Restaurant             Food Court        Thai Restaurant
# 2                Pizza Place             Restaurant         Sandwich Place
# 3  Middle Eastern Restaurant             Restaurant         Sandwich Place
# 4                Snack Place           Burger Joint                 Buffet
#
#   22th Most Common Venue   23th Most Common Venue  \
# 0       Kebab Restaurant              Snack Place
# 1    Japanese Restaurant         Kebab Restaurant
# 2            Snack Place  South Indian Restaurant
# 3            Snack Place  South Indian Restaurant
# 4         Breakfast Spot                   Bistro
#
#           24th Most Common Venue
# 0  Vegetarian / Vegan Restaurant
# 1        South Indian Restaurant
# 2               Asian Restaurant
# 3               Asian Restaurant
# 4               Asian Restaurant
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Plotting a map of chennai and coloring the different neighborhoods based on their cluster labels

# %%
chennai_map=folium.Map([ch_lat,ch_lng],zoom_start=11)

colors_array = cm.rainbow(np.linspace(0, 1, k_hf))
rainbow = [colors.rgb2hex(i) for i in colors_array]

for lat,lng,neighborhood,cluster_label in zip(cluster_df.latitude,cluster_df.longitude,cluster_df.Neighborhood,cluster_df['Cluster Labels']):
    labels="{} Cluster:{}".format(neighborhood,cluster_label)
    folium.CircleMarker(
        [lat,lng],
        radius=5,
        popup=labels,
        color=rainbow[cluster_label],
        fill=True,
        fill_color=rainbow[cluster_label],
        fill_opacity=0.7,
        parse_html=False).add_to(chennai_map)
    
chennai_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ## The above map corresponds to the below clusters. The clusters have been analysed and their prominent charactristics in the desired context have been listed

# %%
hf_restaurant_classification
# Out:
#    Cluster Labels                             High Frequency locations  \
# 0               0                   Indian followed by Pizza & Chinese
# 1               1  Fast food restaurants followed by vegan restaurants
# 2               2         Indian followed by Dessert & Breakfast shops
# 3               3      Pizza place followed by vegetarian & BBQ joints
# 4               4                        Not statistically significant
# 5               5            Indian followed by Chinese and BBQ joints
# 6               6     Vegetarian & Thai followed by Vegan & BBQ joints
#
#                                                                                       Low Frequency Locations
# 0                                                                              BBQ, asian, Cafe & coffe shops
# 1                                                              Indian restaurants followed by exotic cuisines
# 2  South Indian, Snacking & Sandwich places, Pizza places, fast food restaurants & Italian & thai restaurants
# 3                                                                                          Exotic restaurants
# 4                                                                               Not statistically significant
# 5                                                                 Non chinese asian, burger, buffet, snacking
# 6                                                             Pizza places, snacking places & exotic cuisines

# %% [markdown]
# ### The same analysis is carried out on the low frequency restaurants. Due to their overwhelmingly low incidence of less than 5-6 of those venues acorss the city, the stakeholders could choose either one of those relatively confidently but the model is already done so just analysing the cluster woud be required which is easy and identical to what we've done above.

# %% [markdown]
# ## Results and Discussion <a name="results"></a>

# %% [markdown]
# The entire purpose behind this project was to provide an insight into the distribution of restaurants in the city of Chennai in Tamil Nade, India. The analysis focuses on retrieving all the venues in chennai, accurately filtering out the restaurants and clustering them to analyse the neighborhoods. On our analysis, we can clearly see that certain locations clearly have a greater incidence of certain restaurants and a clear lack of others.

# %% [markdown]
# The analysis showed an exceptionally high number of indian restaurants and a reasonably high number of chinese restaurants. Some very key insights were derived in the anaysis. For example, the few major areas that had a major lack of indian restaurants were identified which could be cruical for stakeholders interested in entering the indian restaurant game. Similar insights have shown certain key areas that are definately not suitable for opening massive chain categories like pizza places, vegetarian restaurants etc. For a future design, the data could be fed into an app or olatform where based on the type of restaurant or choice of area, the cluster data, simlilar neighborhoods, distribution of restaurants etc can be easily obtained.

# %% [markdown]
# ## Conclusion <a name="conclusion"></a>

# %% [markdown]
# The purpose of this project was the identify the various restaurant categories and their quantitative distribution in the city of chennai. This is followed up by clustering neighborhoods based on their distribution of restaurants. This will enable stakeholders to indentify neighborhoods that have a lack of a certain type of restaurant and will also help in preventing the establishment of a restaurant in a neighborhood that has an overwhelming excess of that specific restaurant type.

# %% [markdown]
# Final decision on optimal restaurant location will be made by stakeholders based on specific characteristics of neighborhoods and locations in every recommended zone, taking into consideration additional factors like attractiveness of each location ,real estate availability, prices, social and economic dynamics of every neighborhood etc.
